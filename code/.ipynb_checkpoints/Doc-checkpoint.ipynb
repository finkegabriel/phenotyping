# %%
Phenotyping Research By:Gabriel Finke

# %%
import matplotlib.pyplot as plt
#matplotlib inline

from skimage import data,filters

image = data.coins() 

edges = filters.sobel(image)
print(edges)
print("after edges")
plt.imshow(edges, cmap='gray')
plt.show()
# Out:
# [[0.22261811 0.22580966 0.04256528 ... 0.01675295 0.00765711 0.0202113 ]
#  [0.22752914 0.17208326 0.04307036 ... 0.03683979 0.00765711 0.01180548]
#  [0.10007686 0.06139791 0.02499519 ... 0.084638   0.00490196 0.02018751]
#  ...
#  [0.01386484 0.03114192 0.02949335 ... 0.01669548 0.00588235 0.00876889]
#  [0.02752092 0.04030354 0.0335059  ... 0.00571662 0.00980392 0.00438445]
#  [0.02941176 0.05787636 0.0417099  ... 0.00490196 0.00876889 0.00554594]]
# after edges

# %%
#the above is an example of filtering images into grayscale

# %%
#example with woodchips that were taken from pixel 4

# %%
import matplotlib.pyplot as plt
import woodchiparray as chip
#matplotlib inline

from skimage import data,filters

image = chip.woodchip() 
#print("image ",image)
for l in image:
    edges = filters.sobel(l)
    #print("after edges",l)
    plt.imshow(edges, cmap='gray')
    plt.show()
# Out:
# ['../images/WoodChips/2.jpg']
# ../images/WoodChips/2.jpg
# (1, 3024, 4032, 3)
